# %%
# myList = []
# mylist = List()

help([])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
class SinglyLinkedList:
    class Node:
        def __init__(self,data):
            self.data = data
            self.next = None

    def __init__(self):
        self.head = None

    def append(self,value):
        new_node = self.Node(value)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

    def index(self,value):
        #return the position of value in the list if it exist; ValueError otherwise
        i=0
        current = self.head
        while current:
            if current.data == value:
                flag=f"""Position: {i}"""
                break
            else:
                flag=f"""ValueError: Value {value} not exists in the list"""
            current = current.next
            i+=1
        return flag
    
    def insert(self,index,value):
        #Insert value BEFORE index}
        new_node = self.Node(value)
        if not self.head:
            self.head = new_node
        else:
            if index ==  0:
                old_head = self.head
                self.head = new_node
                new_node.next = old_head
            else:
                current = self.head
                prev = None
                counter = 0
                while current.next and index != counter:
                    prev = current
                    current = current.next
                    counter += 1
                if index == counter:
                    prev.next = new_node
                    new_node.next = current
                else:
                    current.next = new_node

    def remove(self,value):
        #Remove the first ocurrence of value
        #raise ValueError if not present
        pass

    def __str__(self):
        current = self.head
        if current == None:
            out = "[]"
        else:
            out = "["
            
        while current:
            if current.next != None:
                out += "%s" % current.data + ", "
            else:
                out += "%s" % current.data + "]"
            current = current.next
        return out
    
    #{Professor Solution
    # def __str__(self):
    #   out="["
    #   current = self.head
    #   if current:
    #       out += "%s" % current.data
    #       current = current.next
    #       while current:
    #           out += ", %s" % current.data
    #           current = current.next
    #   out += "]"
    #   return out
    #}

# %%
x = SinglyLinkedList()

for number in range(1,9):
    x.append(number)

print(x)

print(x.index(4))

# y = []
# for item in range(1,5):
#     y.append(item)

# print(y)

# print(y.index(4))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# Position: 3

# %%
ourlist = SinglyLinkedList()

# %%
ourlist = SinglyLinkedList()
print("Empty List:")
ourlist.insert(100,1)
print(ourlist)

print("Replace the head:")
ourlist.insert(0,0)
print(ourlist)

print("Insert anywhere between head and tail:")
ourlist.insert(1,0.5)
print(ourlist)

print("Insert to replace the tail (append):")
ourlist.insert(3,2)
print(ourlist)
# Out:
# Empty List:
# [1]
# Replace the head:
# [0, 1]
# Insert anywhere between head and tail:
# [0, 0.5, 1]
# Insert to replace the tail (append):
# [0, 0.5, 1, 2]

# %%
class DoublyLinkedList:
    class Node:
        def __init__(self,data):
            self.data = data
            self.next = None
            self.prev = None

    def __init__(self):
        self.head = None

    def append(self,value):
        new_node = self.Node(value)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            new_node.prev = current
            current.next = new_node

    def insert(self,index,value):
        #insert value before an index (but this time, maintain all references)
        pass

    def remove(self,value):
        #remove first instance of value (but this time, maintain all references)
        pass
